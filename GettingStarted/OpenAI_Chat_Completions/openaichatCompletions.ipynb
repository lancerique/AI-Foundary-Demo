# %%
# %pip install azure-ai-projects==2.0.0b2 openai==1.109.1 python-dotenv azure-identity
# Out:
# Collecting azure-ai-projects==2.0.0b2
#   Using cached azure_ai_projects-2.0.0b2-py3-none-any.whl.metadata (63 kB)
# Collecting openai==1.109.1
#   Downloading openai-1.109.1-py3-none-any.whl.metadata (29 kB)
# Collecting python-dotenv
#   Using cached python_dotenv-1.2.1-py3-none-any.whl.metadata (25 kB)
# Collecting azure-identity
#   Using cached azure_identity-1.25.1-py3-none-any.whl.metadata (88 kB)
# Collecting isodate>=0.6.1 (from azure-ai-projects==2.0.0b2)
#   Using cached isodate-0.7.2-py3-none-any.whl.metadata (11 kB)
# Collecting azure-core>=1.35.0 (from azure-ai-projects==2.0.0b2)
#   Using cached azure_core-1.37.0-py3-none-any.whl.metadata (47 kB)
# Collecting typing-extensions>=4.6.0 (from azure-ai-projects==2.0.0b2)
#   Using cached typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting azure-storage-blob>=12.15.0 (from azure-ai-projects==2.0.0b2)
#   Downloading azure_storage_blob-12.27.1-py3-none-any.whl.metadata (26 kB)
# Collecting anyio<5,>=3.5.0 (from openai==1.109.1)
#   Using cached anyio-4.12.0-py3-none-any.whl.metadata (4.3 kB)
# Collecting distro<2,>=1.7.0 (from openai==1.109.1)
#   Using cached distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting httpx<1,>=0.23.0 (from openai==1.109.1)
#   Using cached httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting jiter<1,>=0.4.0 (from openai==1.109.1)
#   Using cached jiter-0.12.0-cp314-cp314-win_amd64.whl.metadata (5.3 kB)
# Collecting pydantic<3,>=1.9.0 (from openai==1.109.1)
#   Using cached pydantic-2.12.5-py3-none-any.whl.metadata (90 kB)
# Collecting sniffio (from openai==1.109.1)
#   Using cached sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting tqdm>4 (from openai==1.109.1)
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting idna>=2.8 (from anyio<5,>=3.5.0->openai==1.109.1)
#   Using cached idna-3.11-py3-none-any.whl.metadata (8.4 kB)
# Collecting certifi (from httpx<1,>=0.23.0->openai==1.109.1)
#   Using cached certifi-2025.11.12-py3-none-any.whl.metadata (2.5 kB)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->openai==1.109.1)
#   Using cached httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Collecting h11>=0.16 (from httpcore==1.*->httpx<1,>=0.23.0->openai==1.109.1)
#   Using cached h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Collecting annotated-types>=0.6.0 (from pydantic<3,>=1.9.0->openai==1.109.1)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.41.5 (from pydantic<3,>=1.9.0->openai==1.109.1)
#   Using cached pydantic_core-2.41.5-cp314-cp314-win_amd64.whl.metadata (7.4 kB)
# Collecting typing-inspection>=0.4.2 (from pydantic<3,>=1.9.0->openai==1.109.1)
#   Using cached typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Collecting cryptography>=2.5 (from azure-identity)
#   Using cached cryptography-46.0.3-cp311-abi3-win_amd64.whl.metadata (5.7 kB)
# Collecting msal>=1.30.0 (from azure-identity)
#   Using cached msal-1.34.0-py3-none-any.whl.metadata (11 kB)
# Collecting msal-extensions>=1.2.0 (from azure-identity)
#   Using cached msal_extensions-1.3.1-py3-none-any.whl.metadata (7.8 kB)
# Collecting requests>=2.21.0 (from azure-core>=1.35.0->azure-ai-projects==2.0.0b2)
#   Using cached requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Collecting cffi>=2.0.0 (from cryptography>=2.5->azure-identity)
#   Using cached cffi-2.0.0-cp314-cp314-win_amd64.whl.metadata (2.6 kB)
# Collecting pycparser (from cffi>=2.0.0->cryptography>=2.5->azure-identity)
#   Using cached pycparser-2.23-py3-none-any.whl.metadata (993 bytes)
# Collecting PyJWT<3,>=1.0.0 (from PyJWT[crypto]<3,>=1.0.0->msal>=1.30.0->azure-identity)
#   Using cached PyJWT-2.10.1-py3-none-any.whl.metadata (4.0 kB)
# Collecting charset_normalizer<4,>=2 (from requests>=2.21.0->azure-core>=1.35.0->azure-ai-projects==2.0.0b2)
#   Using cached charset_normalizer-3.4.4-cp314-cp314-win_amd64.whl.metadata (38 kB)
# Collecting urllib3<3,>=1.21.1 (from requests>=2.21.0->azure-core>=1.35.0->azure-ai-projects==2.0.0b2)
#   Using cached urllib3-2.6.2-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: colorama in c:\users\nikhi\documents\ai foundary u\.venv\lib\site-packages (from tqdm>4->openai==1.109.1) (0.4.6)
# Using cached azure_ai_projects-2.0.0b2-py3-none-any.whl (234 kB)
# Downloading openai-1.109.1-py3-none-any.whl (948 kB)
#    ---------------------------------------- 0.0/948.6 kB ? eta -:--:--
#    --------------------------------- ------ 786.4/948.6 kB 4.2 MB/s eta 0:00:01
#    ---------------------------------------- 948.6/948.6 kB 4.1 MB/s  0:00:00
# Using cached anyio-4.12.0-py3-none-any.whl (113 kB)
# Using cached distro-1.9.0-py3-none-any.whl (20 kB)
# Using cached httpx-0.28.1-py3-none-any.whl (73 kB)
# Using cached httpcore-1.0.9-py3-none-any.whl (78 kB)
# Using cached jiter-0.12.0-cp314-cp314-win_amd64.whl (204 kB)
# Using cached pydantic-2.12.5-py3-none-any.whl (463 kB)
# Using cached pydantic_core-2.41.5-cp314-cp314-win_amd64.whl (2.0 MB)
# Using cached typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Using cached python_dotenv-1.2.1-py3-none-any.whl (21 kB)
# Using cached azure_identity-1.25.1-py3-none-any.whl (191 kB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached azure_core-1.37.0-py3-none-any.whl (214 kB)
# Downloading azure_storage_blob-12.27.1-py3-none-any.whl (428 kB)
# Using cached cryptography-46.0.3-cp311-abi3-win_amd64.whl (3.5 MB)
# Using cached cffi-2.0.0-cp314-cp314-win_amd64.whl (185 kB)
# Using cached h11-0.16.0-py3-none-any.whl (37 kB)
# Using cached idna-3.11-py3-none-any.whl (71 kB)
# Using cached isodate-0.7.2-py3-none-any.whl (22 kB)
# Using cached msal-1.34.0-py3-none-any.whl (116 kB)
# Using cached PyJWT-2.10.1-py3-none-any.whl (22 kB)
# Using cached requests-2.32.5-py3-none-any.whl (64 kB)
# Using cached charset_normalizer-3.4.4-cp314-cp314-win_amd64.whl (107 kB)
# Using cached urllib3-2.6.2-py3-none-any.whl (131 kB)
# Using cached certifi-2025.11.12-py3-none-any.whl (159 kB)
# Using cached msal_extensions-1.3.1-py3-none-any.whl (20 kB)
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Using cached typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Using cached pycparser-2.23-py3-none-any.whl (118 kB)
# Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Installing collected packages: urllib3, typing-extensions, tqdm, sniffio, python-dotenv, PyJWT, pycparser, jiter, isodate, idna, h11, distro, charset_normalizer, certifi, annotated-types, typing-inspection, requests, pydantic-core, httpcore, cffi, anyio, pydantic, httpx, cryptography, azure-core, openai, azure-storage-blob, msal, azure-ai-projects, msal-extensions, azure-identity
#
#    ----------------------------------------  0/31 [urllib3]
#    ----------------------------------------  0/31 [urllib3]
#    ----------------------------------------  0/31 [urllib3]
#    - --------------------------------------  1/31 [typing-extensions]
#    -- -------------------------------------  2/31 [tqdm]
#    -- -------------------------------------  2/31 [tqdm]
#    ----- ----------------------------------  4/31 [python-dotenv]
#    ------ ---------------------------------  5/31 [PyJWT]
#    ------- --------------------------------  6/31 [pycparser]
#    ------- --------------------------------  6/31 [pycparser]
#    ---------- -----------------------------  8/31 [isodate]
#    ----------- ----------------------------  9/31 [idna]
#    ----------- ----------------------------  9/31 [idna]
#    -------------- ------------------------- 11/31 [distro]
#    --------------- ------------------------ 12/31 [charset_normalizer]
#    ------------------- -------------------- 15/31 [typing-inspection]
#    -------------------- ------------------- 16/31 [requests]
#    --------------------- ------------------ 17/31 [pydantic-core]
#    ----------------------- ---------------- 18/31 [httpcore]
#    ----------------------- ---------------- 18/31 [httpcore]
#    ------------------------ --------------- 19/31 [cffi]
#    ------------------------ --------------- 19/31 [cffi]
#    ------------------------- -------------- 20/31 [anyio]
#    ------------------------- -------------- 20/31 [anyio]
#    ------------------------- -------------- 20/31 [anyio]
#    --------------------------- ------------ 21/31 [pydantic]
#    --------------------------- ------------ 21/31 [pydantic]
#    --------------------------- ------------ 21/31 [pydantic]
#    --------------------------- ------------ 21/31 [pydantic]
#    --------------------------- ------------ 21/31 [pydantic]
#    --------------------------- ------------ 21/31 [pydantic]
#    --------------------------- ------------ 21/31 [pydantic]
#    --------------------------- ------------ 21/31 [pydantic]
#    --------------------------- ------------ 21/31 [pydantic]
#    ---------------------------- ----------- 22/31 [httpx]
#    ---------------------------- ----------- 22/31 [httpx]
#    ---------------------------- ----------- 22/31 [httpx]
#    ----------------------------- ---------- 23/31 [cryptography]
#    ----------------------------- ---------- 23/31 [cryptography]
#    ----------------------------- ---------- 23/31 [cryptography]
#    ----------------------------- ---------- 23/31 [cryptography]
#    ----------------------------- ---------- 23/31 [cryptography]
#    ------------------------------ --------- 24/31 [azure-core]
#    ------------------------------ --------- 24/31 [azure-core]
#    ------------------------------ --------- 24/31 [azure-core]
#    ------------------------------ --------- 24/31 [azure-core]
#    ------------------------------ --------- 24/31 [azure-core]
#    -------------------------------- ------- 25/31 [openai]
#    -------------------------------- ------- 25/31 [openai]
#    -------------------------------- ------- 25/31 [openai]
#    -------------------------------- ------- 25/31 [openai]
#    -------------------------------- ------- 25/31 [openai]
#    -------------------------------- ------- 25/31 [openai]
#    -------------------------------- ------- 25/31 [openai]
#    -------------------------------- ------- 25/31 [openai]
#    -------------------------------- ------- 25/31 [openai]
#    -------------------------------- ------- 25/31 [openai]
#    -------------------------------- ------- 25/31 [openai]
#    -------------------------------- ------- 25/31 [openai]
#    -------------------------------- ------- 25/31 [openai]
#    -------------------------------- ------- 25/31 [openai]
#    -------------------------------- ------- 25/31 [openai]
#    -------------------------------- ------- 25/31 [openai]
#    -------------------------------- ------- 25/31 [openai]
#    -------------------------------- ------- 25/31 [openai]
#    -------------------------------- ------- 25/31 [openai]
#    -------------------------------- ------- 25/31 [openai]
#    -------------------------------- ------- 25/31 [openai]
#    -------------------------------- ------- 25/31 [openai]
#    -------------------------------- ------- 25/31 [openai]
#    -------------------------------- ------- 25/31 [openai]
#    -------------------------------- ------- 25/31 [openai]
#    -------------------------------- ------- 25/31 [openai]
#    -------------------------------- ------- 25/31 [openai]
#    -------------------------------- ------- 25/31 [openai]
#    -------------------------------- ------- 25/31 [openai]
#    -------------------------------- ------- 25/31 [openai]
#    -------------------------------- ------- 25/31 [openai]
#    -------------------------------- ------- 25/31 [openai]
#    -------------------------------- ------- 25/31 [openai]
#    -------------------------------- ------- 25/31 [openai]
#    -------------------------------- ------- 25/31 [openai]
#    -------------------------------- ------- 25/31 [openai]
#    -------------------------------- ------- 25/31 [openai]
#    -------------------------------- ------- 25/31 [openai]
#    -------------------------------- ------- 25/31 [openai]
#    -------------------------------- ------- 25/31 [openai]
#    -------------------------------- ------- 25/31 [openai]
#    -------------------------------- ------- 25/31 [openai]
#    -------------------------------- ------- 25/31 [openai]
#    -------------------------------- ------- 25/31 [openai]
#    -------------------------------- ------- 25/31 [openai]
#    -------------------------------- ------- 25/31 [openai]
#    -------------------------------- ------- 25/31 [openai]
#    -------------------------------- ------- 25/31 [openai]
#    -------------------------------- ------- 25/31 [openai]
#    -------------------------------- ------- 25/31 [openai]
#    -------------------------------- ------- 25/31 [openai]
#    -------------------------------- ------- 25/31 [openai]
#    -------------------------------- ------- 25/31 [openai]
#    -------------------------------- ------- 25/31 [openai]
#    -------------------------------- ------- 25/31 [openai]
#    -------------------------------- ------- 25/31 [openai]
#    --------------------------------- ------ 26/31 [azure-storage-blob]
#    --------------------------------- ------ 26/31 [azure-storage-blob]
#    --------------------------------- ------ 26/31 [azure-storage-blob]
#    --------------------------------- ------ 26/31 [azure-storage-blob]
#    --------------------------------- ------ 26/31 [azure-storage-blob]
#    --------------------------------- ------ 26/31 [azure-storage-blob]
#    --------------------------------- ------ 26/31 [azure-storage-blob]
#    ---------------------------------- ----- 27/31 [msal]
#    ---------------------------------- ----- 27/31 [msal]
#    ------------------------------------ --- 28/31 [azure-ai-projects]
#    ------------------------------------ --- 28/31 [azure-ai-projects]
#    ------------------------------------ --- 28/31 [azure-ai-projects]
#    ------------------------------------ --- 28/31 [azure-ai-projects]
#    ------------------------------------ --- 28/31 [azure-ai-projects]
#    ------------------------------------- -- 29/31 [msal-extensions]
#    ------------------------------------- -- 29/31 [msal-extensions]
#    -------------------------------------- - 30/31 [azure-identity]
#    -------------------------------------- - 30/31 [azure-identity]
#    -------------------------------------- - 30/31 [azure-identity]
#    -------------------------------------- - 30/31 [azure-identity]
#    -------------------------------------- - 30/31 [azure-identity]
#    -------------------------------------- - 30/31 [azure-identity]
#    -------------------------------------- - 30/31 [azure-identity]
#    ---------------------------------------- 31/31 [azure-identity]
#
# Successfully installed PyJWT-2.10.1 annotated-types-0.7.0 anyio-4.12.0 azure-ai-projects-2.0.0b2 azure-core-1.37.0 azure-identity-1.25.1 azure-storage-blob-12.27.1 certifi-2025.11.12 cffi-2.0.0 charset_normalizer-3.4.4 cryptography-46.0.3 distro-1.9.0 h11-0.16.0 httpcore-1.0.9 httpx-0.28.1 idna-3.11 isodate-0.7.2 jiter-0.12.0 msal-1.34.0 msal-extensions-1.3.1 openai-1.109.1 pycparser-2.23 pydantic-2.12.5 pydantic-core-2.41.5 python-dotenv-1.2.1 requests-2.32.5 sniffio-1.3.1 tqdm-4.67.1 typing-extensions-4.15.0 typing-inspection-0.4.2 urllib3-2.6.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
from dotenv import load_dotenv
from azure.identity import DefaultAzureCredential
from azure.ai.projects import AIProjectClient
load_dotenv()

foundry_project_endpoint = os.getenv("FOUNDRY_PROJECT_ENDPOINT")
model_deployment_name = os.getenv("MODEL_DEPLOYMENT_NAME")

# %%
project_client = AIProjectClient(
    endpoint=foundry_project_endpoint,
    credential=DefaultAzureCredential()
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 project_client = AIProjectClient(
#       2     endpoint=foundry_project_endpoint,
#       3     credential=DefaultAzureCredential()
#       4 )
#
# File c:\Users\nikhi\Documents\AI Foundary U\.venv\Lib\site-packages\azure\ai\projects\_patch.py:109, in AIProjectClient.__init__(self, endpoint, credential, **kwargs)
#     106 self._kwargs = kwargs.copy()
#     107 self._patched_user_agent = _patch_user_agent(self._kwargs.pop("user_agent", None))
# --> 109 super().__init__(endpoint=endpoint, credential=credential, **kwargs)
#     111 self.telemetry = TelemetryOperations(self)
#
# File c:\Users\nikhi\Documents\AI Foundary U\.venv\Lib\site-packages\azure\ai\projects\_client.py:83, in AIProjectClient.__init__(self, endpoint, credential, **kwargs)
#      81 def __init__(self, endpoint: str, credential: "TokenCredential", **kwargs: Any) -> None:
#      82     _endpoint = "{endpoint}"
# ---> 83     self._config = AIProjectClientConfiguration(endpoint=endpoint, credential=credential, **kwargs)
#      85     _policies = kwargs.pop("policies", None)
#      86     if _policies is None:
#
# File c:\Users\nikhi\Documents\AI Foundary U\.venv\Lib\site-packages\azure\ai\projects\_configuration.py:43, in AIProjectClientConfiguration.__init__(self, endpoint, credential, **kwargs)
#      40 api_version: str = kwargs.pop("api_version", "2025-11-15-preview")
#      42 if endpoint is None:
# ---> 43     raise ValueError("Parameter 'endpoint' must not be None.")
#      44 if credential is None:
#      45     raise ValueError("Parameter 'credential' must not be None.")
#
# ValueError: Parameter 'endpoint' must not be None.

# %%
openai_client = project_client.get_openai_client()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 openai_client = project_client.get_openai_client()
#
# NameError: name 'project_client' is not defined
